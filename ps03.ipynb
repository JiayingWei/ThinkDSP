# %% [markdown]
# # Problem Set 3 - Jiaying Wei

# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import numpy
import math
import csv

# %precision 3
# %matplotlib inline

# %% [markdown]
# **1) At http://www.coindesk.com you can download the daily price of a BitCoin as a CSV file.  Read this file and compute the power spectrum of BitCoin prices as a function of time. Does it resemble white, pink, or Brownian noise?**

# %%
# with open('coindesk-2-1-2015.csv', 'rb') as bitcoin:
#     reader = csv.reader(bitcoin)
#     time = []
#     value = []
#     for row in reader:
#         if len(row) > 1:
#             time.append(row[0][11:18])
#             value.append(row[1])
# time = time[1::]
# value = value[1::]

ys = []
with open('coindesk-2-1-2015.csv', 'rb') as csvfile:
    bit_read = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in bit_read:
        if len(row) >1:
            data = row[1]
            ys.append(data)
ys = np.arrya()
# total_time = int(time[-1].replace(':','')) + 24000
# total_time = str(total_time)
# seconds = int(total_time[0:2]) * 3600 + int(total_time[2:3]) * 60 + int(total_time[4])
# framerate = len(time)/seconds
framerate = 1
bitcoin = thinkdsp.Wave(value, framerate)
bitcoin.plot()
thinkplot.config(title='Bit Coin Prices on 2-1-2015',xlabel='time (s)', ylabel='price ($)')

# %%
bitcoin_spec = bitcoin.make_spectrum()
bitcoin_spec.plot_power()
thinkplot.config(title='Power density plot of Bitcoins on 2-1-2015',xlabel='frequency (Hz)', ylabel='power density', xscale='log', yscale='log', legend=False)

# %% [markdown]
# Looking at the power density plot of Bitcoin today, it looks like the wave is Brownian. This totally makes sense because bitcoins change in price over time by a step from the previous value which is basically how Brownian noise behaves. I hypothesize that all stocks are Brownian. One thing that I'm still curious about is how does the Brownian motion (previous value + step) corrilates with $P = K \frac{1}{f^2}$

# %% [markdown]
# **2) Compute the autocorrelation of BitCoin prices. Does the autocorrelation function decay exponentially? Is there evidence of periodic behavior?**

# %%
def corrcoef(xs, ys):
    return numpy.corrcoef(xs, ys, ddof=0)[0, 1]

def serial_corr(wave, lag=1):
    N = len(wave)
    y1 = wave.ys[lag:]
    y2 = wave.ys[:N-lag]
    corr = corrcoef(y1, y2)
    return corr

def autocorr(wave):
    """Computes and plots the autocorrelation function.

    wave: Wave
    """
    lags = (range(len(wave.ys)//2))
    corrs = [serial_corr(wave, lag) for lag in lags]
    print(type(corrs))
    return lags, corrs

# %%
lags, corrs = autocorr(bitcoin.segment(start=0, duration=600))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a87f91e7813e> in <module>()
# ----> 1 lags, corrs = autocorr(bitcoin.segment(start=0, duration=600))
#
# <ipython-input-4-e6dd185beba7> in autocorr(wave)
#      15     """
#      16     lags = (range(len(wave.ys)//2))
# ---> 17     corrs = [serial_corr(wave, lag) for lag in lags]
#      18     print(type(corrs))
#      19     return lags, corrs
#
# <ipython-input-4-e6dd185beba7> in serial_corr(wave, lag)
#       6     y1 = wave.ys[lag:]
#       7     y2 = wave.ys[:N-lag]
# ----> 8     corr = corrcoef(y1, y2)
#       9     return corr
#      10
#
# <ipython-input-4-e6dd185beba7> in corrcoef(xs, ys)
#       1 def corrcoef(xs, ys):
# ----> 2     return numpy.corrcoef(xs, ys, ddof=0)[0, 1]
#       3
#       4 def serial_corr(wave, lag=1):
#       5     N = len(wave)
#
# /home/jiaying/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in corrcoef(x, y, rowvar, bias, ddof)
#    1937
#    1938     """
# -> 1939     c = cov(x, y, rowvar, bias, ddof)
#    1940     try:
#    1941         d = diag(c)
#
# /home/jiaying/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.pyc in cov(m, y, rowvar, bias, ddof)
#    1883         X = concatenate((X, y), axis)
#    1884
# -> 1885     X -= X.mean(axis=1-axis, keepdims=True)
#    1886     if not rowvar:
#    1887         return (dot(X.T, X.conj()) / fact).squeeze()
#
# /home/jiaying/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      64         dtype = mu.dtype('f8')
#      65
# ---> 66     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      67     if isinstance(ret, mu.ndarray):
#      68         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %% [markdown]
# **3) Use autocorrelation to estimate the pitch of the saxophone recording in 100475__iluppai__saxophone-weep.wav.  What happens if you filter out the fundamental tone?  Is the estimate based on the autocorrelation function consistent with your perceived pitch?**

# %%
saxophone = thinkdsp.read_wave('100475__iluppai__saxophone-weep.wav').segment(start=1, duration=0.3)
saxophone.make_audio()
lags, corrs = autocorr(saxophone)
thinkplot.plot(lags, corrs)
thinkplot.config(xlabel='lag (index)', ylabel='correlation', ylim=[-1, 1])
